# %% [markdown]
# # ASOS_통합_filtered 데이터 EDA

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# url = "https://raw.githubusercontent.com/hahagoodgood/Renewable-Energy-Generation-Projection/main/ASOS_통합_filtered.csv"
df = pd.read_csv("../ASOS_통합_filtered.csv", encoding="utf-8")
df.head()
# Out:
# /var/folders/z4/ffzs6wp57yx7b8s4kpghn4d40000gn/T/ipykernel_96158/2952180959.py:5: DtypeWarning: Columns (60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../ASOS_통합_filtered.csv", encoding="utf-8")
#    지점 지점명          일시  평균기온(°C)  최저기온(°C)  최저기온 시각(hhmi)  최고기온(°C)  \
# 0  90  속초  2013-01-01      -2.0      -6.7          641.0       2.5
# 1  90  속초  2013-01-02      -7.0      -9.8         2341.0      -1.3
# 2  90  속초  2013-01-03      -7.6     -11.5          716.0      -3.1
# 3  90  속초  2013-01-04      -5.2     -10.4          640.0       0.3
# 4  90  속초  2013-01-05      -1.8      -7.4          124.0       1.9
#
#    최고기온 시각(hhmi)  강수 계속시간(hr)  10분 최다 강수량(mm)  10분 최다강수량 시각(hhmi)  \
# 0         1352.0         0.75             NaN                 NaN
# 1            1.0         1.17             NaN                 NaN
# 2         1346.0          NaN             NaN                 NaN
# ...
